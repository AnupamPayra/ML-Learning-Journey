# %% [markdown]
# ## Algerian Forest Fires Dataset
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.

# %% [markdown]
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Algerian_forest_fires_dataset.csv', header=1) #here header=1 help to take 1st record as individual features

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.columns = [x.strip().lower() for x in dataset.columns ]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   temperature  245 non-null    object
#  4   rh           245 non-null    object
#  5   ws           245 non-null    object
#  6   rain         245 non-null    object
#  7   ffmc         245 non-null    object
#  8   dmc          245 non-null    object
#  9   dc           245 non-null    object
#  10  isi          245 non-null    object
#  11  bui          245 non-null    object
#  12  fwi          245 non-null    object
#  13  classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# # Data Cleaning process --

# %%
df = dataset.copy()

# %%
df.head(2)
# Out:
#   day month  year temperature  rh  ws rain  ffmc  dmc   dc  isi  bui  fwi  \
# 0  01    06  2012          29  57  18    0  65.7  3.4  7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13  1.3  64.4  4.1  7.6    1  3.9  0.4
#
#        classes
# 0  not fire
# 1  not fire

# %% [markdown]
# ### Handling missing value

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# temperature    1
# rh             1
# ws             1
# rain           1
# ffmc           1
# dmc            1
# dc             1
# isi            1
# bui            1
# fwi            1
# classes        2
# dtype: int64

# %%
df[df.isnull().any(axis=1)] # It just help to see column wise missing value.
# Out:
#                                day month  year temperature   rh   ws rain  \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 167                             14    07  2012          37   37   18  0.2
#
#      ffmc   dmc      dc   isi   bui      fwi classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN     NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire        NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index, here creating a new column based on the Region
#
# 1 : "Bejaia Region Dataset"
#
# 2 : "Sidi-Bel Abbes Region Dataset"
#
# Add new column with region

# %%
df.loc[:122, "region"] = 0
df.loc[122:, "region"] = 1

# %%
df['region'] = df['region'].astype('int')

# %%
df.dtypes
# Out:
# day            object
# month          object
# year           object
# temperature    object
# rh             object
# ws             object
# rain           object
# ffmc           object
# dmc            object
# dc             object
# isi            object
# bui            object
# fwi            object
# classes        object
# region          int64
# dtype: object

# %%
df.drop(index=122, inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     day month  year temperature  rh  ws rain  ffmc   dmc      dc   isi   bui  \
# 167  14    07  2012          37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          fwi classes  region
# 167  fire        NaN       1

# %%
df['classes'] = df['classes'].fillna(df['classes'].mode()[0])

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# temperature    0
# rh             0
# ws             0
# rain           0
# ffmc           0
# dmc            0
# dc             0
# isi            0
# bui            0
# fwi            0
# classes        0
# region         0
# dtype: int64

# %%
df.reset_index(drop=True)
# Out:
#     day month  year temperature  rh  ws  rain  ffmc  dmc    dc  isi   bui  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 240  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 241  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 242  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 243  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 244  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      fwi       classes  region
# 0    0.5   not fire          0
# ...

# %%
df.shape
# Out:
# (245, 15)

# %%
df.loc[[122]] # Feature name contain as record at 122 due second reigon dataset.
# Out:
#      day  month  year  temperature   rh   ws   rain  ffmc  dmc  dc  isi  bui  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      fwi    classes  region
# 122  FWI  Classes         1

# %%
df.drop(index=122, inplace=True)
df.reset_index(drop=True)
# Out:
#     day month  year temperature  rh  ws  rain  ffmc  dmc    dc  isi   bui  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      fwi       classes  region
# 0    0.5   not fire          0
# ...

# %%
for feature in ['day', 'month',	'year',	'temperature',	'rh',	'ws']:
    df[feature] = df[feature].astype('int')

# %%
df.dtypes
# Out:
# day             int64
# month           int64
# year            int64
# temperature     int64
# rh              int64
# ws              int64
# rain           object
# ffmc           object
# dmc            object
# dc             object
# isi            object
# bui            object
# fwi            object
# classes        object
# region          int64
# dtype: object

# %%
df['rain'] = df['rain'].astype(float)
df['ffmc'] = df['ffmc'].astype(float)
df['dmc'] = df['dmc'].astype(float)

# %% [markdown]
# df['dc'] = df['dc'].astype(float) # -> error occuring bcz it contain '14.6 9' at 166

# %%
df[df['dc'] == '14.6 9']
# Out:
#      day  month  year  temperature  rh  ws  rain  ffmc   dmc      dc   isi  \
# 166   14      7  2012           37  37  18   0.2  88.9  12.9  14.6 9  12.5
#
#       bui      fwi  classes  region
# 166  10.4  fire     fire          1

# %%
df.loc[166, 'dc'] = df.loc[166, 'dc'].split(' ')[0]

# %%
df['isi'] = df['isi'].astype(float)
df['bui'] = df['bui'].astype(float)

# %% [markdown]
# ValueError: could not convert string to float: 'fire   '

# %%
df[df['fwi'] == 'fire   ']
# Out:
#      day  month  year  temperature  rh  ws  rain  ffmc   dmc    dc   isi  \
# 166   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
#
#       bui      fwi  classes  region
# 166  10.4  fire     fire          1

# %%
df.loc[166, 'fwi'] = df['fwi'].mode()[0]

# %%
df['fwi'] = df['fwi'].astype(float)

# %%
df['dc'] = df['dc'].astype(float)

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# temperature      int64
# rh               int64
# ws               int64
# rain           float64
# ffmc           float64
# dmc            float64
# dc             float64
# isi            float64
# bui            float64
# fwi            float64
# classes         object
# region           int64
# dtype: object

# %%
df.describe()
# Out:
#               day       month    year  temperature          rh          ws  \
# count  244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# mean    15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std      8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              rain        ffmc         dmc          dc         isi         bui  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361   49.288115    4.774180   16.664754
# ...

# %%
df.to_csv('Cleaned_forest_dataset.csv', index=False)
