# %%
import pandas as pd
import numpy as np
import warnings

# %%
df = pd.read_csv('cardekho_imputated.csv')

# %%
df.drop(columns=['Unnamed: 0','car_name'], axis=1, inplace=True)

# %%
df.head()
# Out:
#      brand     model  vehicle_age  km_driven seller_type fuel_type  \
# 0   Maruti      Alto            9     120000  Individual    Petrol
# 1  Hyundai     Grand            5      20000  Individual    Petrol
# 2  Hyundai       i20           11      60000  Individual    Petrol
# 3   Maruti      Alto            9      37000  Individual    Petrol
# 4     Ford  Ecosport            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# 1            Manual    18.90    1197      82.00      5         550000
# 2            Manual    17.00    1197      80.00      5         215000
# 3            Manual    20.92     998      67.10      5         226000
# 4            Manual    22.77    1498      98.59      5         570000

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %%
len(df['model'].unique())
# Out:
# 120

# %%
df['brand'] = df['brand'].str.strip().str.title()

# %%
x = df[[feature for feature in df.columns if feature != "selling_price"]]
y = df['selling_price']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Encoding --

# %%
categorical_feature = x.select_dtypes(include='object').columns
numerical_features = x.select_dtypes(exclude='object').columns

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

oh_encoder = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
std_scaler = StandardScaler()

processor = ColumnTransformer([
    ("OneHotEncoder", oh_encoder, categorical_feature),
    ("StandardScaler", std_scaler, numerical_features)
])

# %%
x_train = processor.fit_transform(x_train)
x_test = processor.transform(x_test)
# Out:
# C:\Users\anupa\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# # Different Model training--

# %%
def metric_eval(true, pred):
    mae = mean_absolute_error(true, pred)
    mse = mean_squared_error(true, pred)
    r2 = r2_score(true, pred)
    rmse = np.sqrt(mse)
    return mae, mse, rmse, r2

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
models = {
    "Linear Regression" : LinearRegression(),
    "Ridge" : Ridge(),
    "Lasso" : Lasso(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest" : RandomForestRegressor(),
    "Ada Boost" : AdaBoostRegressor(),
    "Gradient Boost" : GradientBoostingRegressor()
}

for i in range(len(models)):
    model = list(models.values())[i]
    model.fit(x_train, y_train)

    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)

    tr_mae, tr_mse, tr_rmse, tr_r2 =metric_eval(y_train, train_pred)
    t_mae, t_mse, t_rmse, t_r2 =metric_eval(y_test, test_pred)

    print(f"For {list(models.keys())[i]} model -----\n")
    print('Model performance for Training set')
    print("- Mean Squared Error: {:.4f}".format(tr_mse))
    print("- Root Mean Squared Error: {:.4f}".format(tr_rmse))
    print("- Mean Absolute Error: {:.4f}".format(tr_mae))
    print("- R2 Score: {:.4f}".format(tr_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Mean Squared Error: {:.4f}".format(t_mse))
    print("- Root Mean Squared Error: {:.4f}".format(t_rmse))
    print("- Mean Absolute Error: {:.4f}".format(t_mae))
    print("- R2 Score: {:.4f}".format(t_r2))
    
    print('='*35)
    print('\n')
# Out:
# For Linear Regression model -----
#
# Model performance for Training set
# - Mean Squared Error: 111927776457.1274
# - Root Mean Squared Error: 334556.0887
# - Mean Absolute Error: 164483.3289
# - R2 Score: 0.8612
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 171203460353.7639
# - Root Mean Squared Error: 413767.3989
# - Mean Absolute Error: 181546.1412
# - R2 Score: 0.7799
# ===================================
#
#
# For Ridge model -----
#
# Model performance for Training set
# - Mean Squared Error: 129778203994.8247
# - Root Mean Squared Error: 360247.4205
# - Mean Absolute Error: 175709.7039
# - R2 Score: 0.8391
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 180115732071.6005
# - Root Mean Squared Error: 424400.4383
# - Mean Absolute Error: 192198.8755
# - R2 Score: 0.7684
# ===================================
# C:\Users\anupa\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+14, tolerance: 9.322e+11
#   model = cd_fast.enet_coordinate_descent(
# For Lasso model -----
#
# Model performance for Training set
# - Mean Squared Error: 111928214047.9011
# - Root Mean Squared Error: 334556.7426
# - Mean Absolute Error: 164492.3434
# - R2 Score: 0.8612
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 173666854470.7046
# - Root Mean Squared Error: 416733.5533
# - Mean Absolute Error: 182192.7574
# - R2 Score: 0.7767
# ===================================
#
#
# For Decision Tree model -----
#
# Model performance for Training set
# - Mean Squared Error: 426210181.9807
# - Root Mean Squared Error: 20644.8585
# - Mean Absolute Error: 4991.7517
# - R2 Score: 0.9995
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 90263453826.9783
# - Root Mean Squared Error: 300438.7688
# - Mean Absolute Error: 125138.2883
# - R2 Score: 0.8839
# ===================================
#
#
# For Random Forest model -----
#
# Model performance for Training set
# - Mean Squared Error: 19060015298.1614
# - Root Mean Squared Error: 138058.0142
# - Mean Absolute Error: 38946.8328
# - R2 Score: 0.9764
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 54713438797.3442
# - Root Mean Squared Error: 233909.0396
# - Mean Absolute Error: 102629.0714
# - R2 Score: 0.9297
# ===================================
#
#
# For Ada Boost model -----
#
# Model performance for Training set
# - Mean Squared Error: 271635988678.6477
# - Root Mean Squared Error: 521187.0957
# - Mean Absolute Error: 453316.2018
# - R2 Score: 0.6632
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 311401038182.6005
# - Root Mean Squared Error: 558033.1873
# - Mean Absolute Error: 471838.1568
# - R2 Score: 0.5996
# ===================================
#
#
# For Gradient Boost model -----
#
# Model performance for Training set
# - Mean Squared Error: 38126426909.6117
# - Root Mean Squared Error: 195259.8958
# - Mean Absolute Error: 112674.4178
# - R2 Score: 0.9527
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 63020149440.9675
# - Root Mean Squared Error: 251038.1434
# - Mean Absolute Error: 129017.9473
# - R2 Score: 0.9190
# ===================================

# %% [markdown]
# # Hyperparameter tuning

# %%
dt_params = {
    'criterion' : ['squared_error', 'absolute_error', 'poisson'],
    'splitter' : ['best', 'random'],
    'max_depth': [5, 10, 15, 20, 25, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10]
    
}

rf_params = {
    'criterion' : ['squared_error', 'absolute_error', 'poisson'],
    'max_depth' : [40, 60, 80, 100, 120],
    'min_samples_split' : [2, 3, 4, 8, 10],
    'min_samples_leaf': [1, 2, 5, 10]
}

gb = {
    'loss' : ['squared_error', 'absolute_error', 'huber', 'quantile'],
    'learning_rate' : [0.01, 0.03, 0.05, 0.1, 0.5],
    'n_estimators' : [80, 100, 130, 150, 180],
    'criterion' : ['friedman_mse', 'squared_error'],
    'max_depth' : [40, 60, 80, 100, 120],
    'min_samples_split' : [2, 3, 4, 8, 10],
    'min_samples_leaf': [1, 2, 5, 10]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

models_best_params = {}

models = [
    ("Decision Tree", DecisionTreeRegressor(), dt_params),
    ("Random Forest", RandomForestRegressor(), rf_params),
    ("Gradient Boost", GradientBoostingRegressor(), gb)
]

for name, model, params in models:
    randCv = RandomizedSearchCV(estimator=model,
                      param_distributions=params,
                      cv=4,
                      n_jobs=-1,
                      random_state=42,
                      scoring='r2')
    randCv.fit(x_train, y_train)
    models_best_params[name] = [randCv.best_params_, randCv.best_score_]
    
for val in models_best_params:
    print(models_best_params[val][0])
    print(models_best_params[val][1])
# Out:
# {'splitter': 'best', 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 10, 'criterion': 'absolute_error'}
# 0.8574898342746015
# {'min_samples_split': 8, 'min_samples_leaf': 1, 'max_depth': 40, 'criterion': 'poisson'}
# 0.8632181921198969
# {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 120, 'loss': 'squared_error', 'learning_rate': 0.05, 'criterion': 'squared_error'}
# 0.8676262593289423

# %% [markdown]
# # Final Model comaparision

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
models = {
    "Decision Tree" : DecisionTreeRegressor(splitter='best', min_samples_split= 5, min_samples_leaf= 2, max_depth= 10, criterion= 'absolute_error'),
    "Random Forest" : RandomForestRegressor(min_samples_split= 8, min_samples_leaf= 1, max_depth= 40, criterion= 'poisson'),
    "Gradient Boost" : GradientBoostingRegressor(n_estimators= 150, min_samples_split= 10, min_samples_leaf= 1, max_depth= 120, loss= 'squared_error', learning_rate= 0.05, criterion= 'squared_error')
}

for i in range(len(models)):
    model = list(models.values())[i]
    model.fit(x_train, y_train)

    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)

    tr_mae, tr_mse, tr_rmse, tr_r2 =metric_eval(y_train, train_pred)
    t_mae, t_mse, t_rmse, t_r2 =metric_eval(y_test, test_pred)

    print(f"For {list(models.keys())[i]} model -----\n")
    print('Model performance for Training set')
    print("- Mean Squared Error: {:.4f}".format(tr_mse))
    print("- Root Mean Squared Error: {:.4f}".format(tr_rmse))
    print("- Mean Absolute Error: {:.4f}".format(tr_mae))
    print("- R2 Score: {:.4f}".format(tr_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Mean Squared Error: {:.4f}".format(t_mse))
    print("- Root Mean Squared Error: {:.4f}".format(t_rmse))
    print("- Mean Absolute Error: {:.4f}".format(t_mae))
    print("- R2 Score: {:.4f}".format(t_r2))
    
    print('='*35)
    print('\n')
# Out:
# For Decision Tree model -----
#
# Model performance for Training set
# - Mean Squared Error: 43194950683.5093
# - Root Mean Squared Error: 207833.9498
# - Mean Absolute Error: 87259.0414
# - R2 Score: 0.9464
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 111658840972.1321
# - Root Mean Squared Error: 334153.9181
# - Mean Absolute Error: 125216.9413
# - R2 Score: 0.8564
# ===================================
#
#
# For Random Forest model -----
#
# Model performance for Training set
# - Mean Squared Error: 42806429206.7747
# - Root Mean Squared Error: 206897.1464
# - Mean Absolute Error: 60664.6303
# - R2 Score: 0.9469
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 57679635312.2590
# - Root Mean Squared Error: 240165.8496
# - Mean Absolute Error: 103579.7469
# - R2 Score: 0.9258
# ===================================
#
#
# For Gradient Boost model -----
#
# Model performance for Training set
# - Mean Squared Error: 476270273.1063
# - Root Mean Squared Error: 21823.6173
# - Mean Absolute Error: 8483.9531
# - R2 Score: 0.9994
# ----------------------------------
# Model performance for Test set
# - Mean Squared Error: 54754483340.3558
# - Root Mean Squared Error: 233996.7593
# - Mean Absolute Error: 107963.4094
# - R2 Score: 0.9296
# ===================================
